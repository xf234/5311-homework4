# %%
import pandas as pd
file_path = '/Users/xiaoyufan/Desktop/candy-data.csv'
df = pd.read_csv(file_path)
df
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                    100 Grand          1       0        1               0
# 1                 3 Musketeers          1       0        0               0
# 2                     One dime          0       0        0               0
# 3                  One quarter          0       0        0               0
# 4                    Air Heads          0       1        0               0
# ..                         ...        ...     ...      ...             ...
# 80                   Twizzlers          0       1        0               0
# 81                    Warheads          0       1        0               0
# 82        Welch's Fruit Snacks          0       1        0               0
# 83  Werther's Original Caramel          0       0        1               0
# 84                    Whoppers          1       0        0               0
#
# ...

# %%
def get_ingredients(row):
    ingredients = []
    if row['chocolate'] == 1:
        ingredients.append('chocolate')
    if row['fruity'] == 1:
        ingredients.append('fruity')
    if row['caramel'] == 1:
        ingredients.append('caramel')
    if row['peanutyalmondy'] == 1:
        ingredients.append('peanutyalmondy')
    if row['nougat'] == 1:
        ingredients.append('nougat')
    if row['crispedricewafer'] == 1:
        ingredients.append('crispedricewafer')
    if row['hard'] == 1:
        ingredients.append('hard')
    if row['bar'] == 1:
        ingredients.append('bar')
    if row['pluribus'] == 1:
        ingredients.append('pluribus')
    return ingredients

# Apply the function to each row of the DataFrame and create the new column
df['ingredients'] = df.apply(get_ingredients, axis=1)

# Display the DataFrame to verify the new column
df
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                    100 Grand          1       0        1               0
# 1                 3 Musketeers          1       0        0               0
# 2                     One dime          0       0        0               0
# 3                  One quarter          0       0        0               0
# 4                    Air Heads          0       1        0               0
# ..                         ...        ...     ...      ...             ...
# 80                   Twizzlers          0       1        0               0
# 81                    Warheads          0       1        0               0
# 82        Welch's Fruit Snacks          0       1        0               0
# 83  Werther's Original Caramel          0       0        1               0
# 84                    Whoppers          1       0        0               0
#
# ...

# %%
columns_to_drop = ['chocolate', 'fruity', 'caramel', 'peanutyalmondy', 'nougat', 'crispedricewafer', 'hard', 'bar', 'pluribus']
df.drop(columns=columns_to_drop, inplace=True)

# Display the DataFrame to verify the columns have been deleted
df.head()
# Out:
#   competitorname  sugarpercent  pricepercent  winpercent  \
# 0      100 Grand         0.732         0.860   66.971725
# 1   3 Musketeers         0.604         0.511   67.602936
# 2       One dime         0.011         0.116   32.261086
# 3    One quarter         0.011         0.511   46.116505
# 4      Air Heads         0.906         0.511   52.341465
#
#                                    ingredients
# 0  [chocolate, caramel, crispedricewafer, bar]
# 1                     [chocolate, nougat, bar]
# 2                                           []
# 3                                           []
# 4                                     [fruity]

# %%
df.to_csv('/Users/xiaoyufan/Desktop/candy_data_new.csv', index=False)
